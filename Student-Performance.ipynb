# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data1=pd.read_csv('student-mat.csv',delimiter=';')          #read csv file of data1

# %%
data1.head()                                                #showing the first 5 observations
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
data1.drop(['G1','G2'],axis=1,inplace=True)                           #droppping columns  G1 ,G2

# %%
data1.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   internet romantic  famrel  freetime  goout Dalc Walc health absences  G3
# 0       no       no       4         3      4    1    1      3        6   6
# 1      yes       no       5         3      3    1    1      3        4   6
# 2      yes       no       4         3      2    2    3      3       10  10
# 3      yes      yes       3         2      2    1    1      5        2  15
# 4       no       no       4         3      2    1    2      5        4  10
#
# [5 rows x 31 columns]

# %%
data1.shape
# Out:
# (395, 31)

# %%
data2=pd.read_csv('student-por.csv',delimiter=';')                       #read csv file of data2

# %%
data2.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
data2.drop(['G1','G2'],axis=1,inplace=True)

# %%
data2.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   internet romantic  famrel  freetime  goout Dalc Walc health absences  G3
# 0       no       no       4         3      4    1    1      3        4  11
# 1      yes       no       5         3      3    1    1      3        2  11
# 2      yes       no       4         3      2    2    3      3        6  12
# 3      yes      yes       3         2      2    1    1      5        0  14
# 4       no       no       4         3      2    1    2      5        0  13
#
# [5 rows x 31 columns]

# %%
data2.shape
# Out:
# (649, 31)

# %%
frames=[data1,data2]                                                          #concatenating the 2 datasets
data=pd.concat(frames)

# %%
data
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
data.reset_index(inplace = True)                                    #reseting the default index value

# %%
data
# Out:
#       index school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# 0         0     GP   F   18       U     GT3       A     4     4   at_home
# 1         1     GP   F   17       U     GT3       T     1     1   at_home
# 2         2     GP   F   15       U     LE3       T     1     1   at_home
# 3         3     GP   F   15       U     GT3       T     4     2    health
# 4         4     GP   F   16       U     GT3       T     3     3     other
# ...     ...    ...  ..  ...     ...     ...     ...   ...   ...       ...
# 1039    644     MS   F   19       R     GT3       T     2     3  services
# 1040    645     MS   F   18       U     LE3       T     3     1   teacher
# 1041    646     MS   F   18       U     GT3       T     1     1     other
# 1042    647     MS   M   17       U     LE3       T     3     1  services
# 1043    648     MS   M   18       R     LE3       T     3     2  services
#
#       ... internet romantic famrel  freetime  goout  Dalc Walc health  \
# ...

# %%
data.columns
# Out:
# Index(['index', 'school', 'sex', 'age', 'address', 'famsize', 'Pstatus',
#        'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime',
#        'studytime', 'failures', 'schoolsup', 'famsup', 'paid', 'activities',
#        'nursery', 'higher', 'internet', 'romantic', 'famrel', 'freetime',
#        'goout', 'Dalc', 'Walc', 'health', 'absences', 'G3'],
#       dtype='object')

# %%
data.isnull().sum()                                              #checking for null values
# Out:
# index         0
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G3            0
# dtype: int64

# %%
data['school'].unique()                                             #checking for unique categories
# Out:
# array(['GP', 'MS'], dtype=object)

# %%
data['school']=data['school'].map({'GP':0, 'MS':1})                 #replacing categorical variables with numbers

# %%
data.head()
# Out:
#    index  school sex  age address famsize Pstatus  Medu  Fedu     Mjob  ...  \
# 0      0       0   F   18       U     GT3       A     4     4  at_home  ...
# 1      1       0   F   17       U     GT3       T     1     1  at_home  ...
# 2      2       0   F   15       U     LE3       T     1     1  at_home  ...
# 3      3       0   F   15       U     GT3       T     4     2   health  ...
# 4      4       0   F   16       U     GT3       T     3     3    other  ...
#
#   internet romantic famrel  freetime  goout  Dalc Walc health absences  G3
# 0       no       no      4         3      4     1    1      3        6   6
# 1      yes       no      5         3      3     1    1      3        4   6
# 2      yes       no      4         3      2     2    3      3       10  10
# 3      yes      yes      3         2      2     1    1      5        2  15
# 4       no       no      4         3      2     1    2      5        4  10
#
# [5 rows x 32 columns]

# %%
data.describe()
# Out:
#              index       school          age         Medu         Fedu  \
# count  1044.000000  1044.000000  1044.000000  1044.000000  1044.000000
# mean    275.949234     0.260536    16.726054     2.603448     2.387931
# std     174.819941     0.439138     1.239975     1.124907     1.099938
# min       0.000000     0.000000    15.000000     0.000000     0.000000
# 25%     130.000000     0.000000    16.000000     2.000000     1.000000
# 50%     260.500000     0.000000    17.000000     3.000000     2.000000
# 75%     391.000000     1.000000    18.000000     4.000000     3.000000
# max     648.000000     1.000000    22.000000     4.000000     4.000000
#
#         traveltime    studytime     failures       famrel     freetime  \
# count  1044.000000  1044.000000  1044.000000  1044.000000  1044.000000
# mean      1.522989     1.970307     0.264368     3.935824     3.201149
# std       0.731727     0.834353     0.656142     0.933401     1.031507
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1044 entries, 0 to 1043
# Data columns (total 32 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index       1044 non-null   int64
#  1   school      1044 non-null   int64
#  2   sex         1044 non-null   object
#  3   age         1044 non-null   int64
#  4   address     1044 non-null   object
#  5   famsize     1044 non-null   object
#  6   Pstatus     1044 non-null   object
#  7   Medu        1044 non-null   int64
#  8   Fedu        1044 non-null   int64
#  9   Mjob        1044 non-null   object
#  10  Fjob        1044 non-null   object
#  11  reason      1044 non-null   object
#  12  guardian    1044 non-null   object
#  13  traveltime  1044 non-null   int64
#  14  studytime   1044 non-null   int64
#  15  failures    1044 non-null   int64
#  16  schoolsup   1044 non-null   object
#  17  famsup      1044 non-null   object
#  18  paid        1044 non-null   object
# ...

# %%
data['Mjob']
# Out:
# 0        at_home
# 1        at_home
# 2        at_home
# 3         health
# 4          other
#           ...
# 1039    services
# 1040     teacher
# 1041       other
# 1042    services
# 1043    services
# Name: Mjob, Length: 1044, dtype: object

# %%
data['sex'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
data['sex']=data['sex'].map({'F':0, 'M':1})

# %%
data.famsize.unique()
# Out:
# array(['GT3', 'LE3'], dtype=object)

# %%
data.famsize=data.famsize.map({'GT3':0, 'LE3':1})

# %%
data.Pstatus.unique()
# Out:
# array(['A', 'T'], dtype=object)

# %%
data.Pstatus=data.Pstatus.map({'A':0, 'T':1})

# %%
data.Mjob.unique()
# Out:
# array(['at_home', 'health', 'other', 'services', 'teacher'], dtype=object)

# %%
data.Mjob=data.Mjob.map({'at_home':0, 'health':1, 'other':2, 'services':3, 'teacher':4})

# %%
data.Fjob.unique()
# Out:
# array(['teacher', 'other', 'services', 'health', 'at_home'], dtype=object)

# %%
data.Fjob=data.Fjob.map({'at_home':0, 'health':1, 'other':2, 'services':3, 'teacher':4})

# %%
data.reason.unique()
# Out:
# array(['course', 'other', 'home', 'reputation'], dtype=object)

# %%
data.reason=data.reason.map({'course':0, 'other':1, 'home':2, 'reputation':3})

# %%
data.guardian.unique()
# Out:
# array(['mother', 'father', 'other'], dtype=object)

# %%
data.guardian=data.guardian.map({'mother':0, 'father':1, 'other':2})

# %%
data.traveltime.unique()
# Out:
# array([2, 1, 3, 4], dtype=int64)

# %%
data.studytime.unique()
# Out:
# array([2, 3, 1, 4], dtype=int64)

# %%
data.failures.unique()
# Out:
# array([0, 3, 2, 1], dtype=int64)

# %%
data.schoolsup.unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
data.schoolsup=data.schoolsup.map({'yes':1,'no':0})

# %%
data.famsup.unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
data.famsup=data.famsup.map({'no':0,'yes':1})

# %%
data.paid.unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
data.paid=data.paid.map({'no':0,'yes':1})

# %%
data.activities.unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
data.activities=data.activities.map({'no':0,'yes':1})

# %%
data.nursery.unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
data.nursery=data.nursery.map({'no':0,'yes':1})

# %%
data.higher.unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
data.higher=data.higher.map({'no':0,'yes':1})

# %%
data.internet.unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
data.internet=data.internet.map({'no':0,'yes':1})

# %%
data.head()
# Out:
#    index  school  sex  age address  famsize  Pstatus  Medu  Fedu  Mjob  ...  \
# 0      0       0    0   18       U        0        0     4     4     0  ...
# 1      1       0    0   17       U        0        1     1     1     0  ...
# 2      2       0    0   15       U        1        1     1     1     0  ...
# 3      3       0    0   15       U        0        1     4     2     1  ...
# 4      4       0    0   16       U        0        1     3     3     2  ...
#
#    internet  romantic  famrel  freetime  goout  Dalc  Walc  health  absences  \
# 0         0        no       4         3      4     1     1       3         6
# 1         1        no       5         3      3     1     1       3         4
# 2         1        no       4         3      2     2     3       3        10
# 3         1       yes       3         2      2     1     1       5         2
# 4         0        no       4         3      2     1     2       5         4
#
#    G3
# 0   6
# 1   6
# 2  10
# 3  15
# 4  10
# ...

# %%
data.romantic.unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
data.romantic=data.romantic.map({'no':0,'yes':1})

# %%
data.head()
# Out:
#    index  school  sex  age address  famsize  Pstatus  Medu  Fedu  Mjob  ...  \
# 0      0       0    0   18       U        0        0     4     4     0  ...
# 1      1       0    0   17       U        0        1     1     1     0  ...
# 2      2       0    0   15       U        1        1     1     1     0  ...
# 3      3       0    0   15       U        0        1     4     2     1  ...
# 4      4       0    0   16       U        0        1     3     3     2  ...
#
#    internet  romantic  famrel  freetime  goout  Dalc  Walc  health  absences  \
# 0         0         0       4         3      4     1     1       3         6
# 1         1         0       5         3      3     1     1       3         4
# 2         1         0       4         3      2     2     3       3        10
# 3         1         1       3         2      2     1     1       5         2
# 4         0         0       4         3      2     1     2       5         4
#
#    G3
# 0   6
# 1   6
# 2  10
# 3  15
# 4  10
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1044 entries, 0 to 1043
# Data columns (total 32 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index       1044 non-null   int64
#  1   school      1044 non-null   int64
#  2   sex         1044 non-null   int64
#  3   age         1044 non-null   int64
#  4   address     1044 non-null   object
#  5   famsize     1044 non-null   int64
#  6   Pstatus     1044 non-null   int64
#  7   Medu        1044 non-null   int64
#  8   Fedu        1044 non-null   int64
#  9   Mjob        1044 non-null   int64
#  10  Fjob        1044 non-null   int64
#  11  reason      1044 non-null   int64
#  12  guardian    1044 non-null   int64
#  13  traveltime  1044 non-null   int64
#  14  studytime   1044 non-null   int64
#  15  failures    1044 non-null   int64
#  16  schoolsup   1044 non-null   int64
#  17  famsup      1044 non-null   int64
#  18  paid        1044 non-null   int64
# ...

# %%
data['Fjob']
# Out:
# 0       4
# 1       2
# 2       2
# 3       3
# 4       2
#        ..
# 1039    2
# 1040    3
# 1041    2
# 1042    3
# 1043    2
# Name: Fjob, Length: 1044, dtype: int64

# %%
data.drop(['index','address'],axis=1,inplace=True)

# %%
sns.relplot(x='famrel',y='G3',data=data)

# %%
sns.relplot(x='higher',y='G3',data=data)

# %%
sns.relplot(x='famsize',y='G3',data=data)

# %%
sns.relplot(x='Pstatus',y='G3',data=data)

# %%
sns.relplot(x='romantic',y='G3',data=data)

# %%
sns.relplot(x='school',y='G3',data=data)

# %%
sns.relplot(x='health',y='G3',data=data)

# %%
sns.relplot(x='goout',y='G3',data=data)

# %%
sns.relplot(x='sex',y='G3',data=data)

# %%
sns.relplot(x='absences',y='G3',data=data)

# %%
data
# Out:
#       school  sex  age  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  reason  ...  \
# 0          0    0   18        0        0     4     4     0     4       0  ...
# 1          0    0   17        0        1     1     1     0     2       0  ...
# 2          0    0   15        1        1     1     1     0     2       1  ...
# 3          0    0   15        0        1     4     2     1     3       2  ...
# 4          0    0   16        0        1     3     3     2     2       2  ...
# ...      ...  ...  ...      ...      ...   ...   ...   ...   ...     ...  ...
# 1039       1    0   19        0        1     2     3     3     2       0  ...
# 1040       1    0   18        1        1     3     1     4     3       0  ...
# 1041       1    0   18        0        1     1     1     2     2       0  ...
# 1042       1    1   17        1        1     3     1     3     3       0  ...
# 1043       1    1   18        1        1     3     2     3     2       0  ...
#
# ...

# %%
data.drop(['famrel','famsize','Pstatus'],axis=1,inplace=True)

# %%
data.corr()
# Out:
#               school       sex       age      Medu      Fedu      Mjob  \
# school      1.000000 -0.074955  0.169938 -0.235114 -0.187611 -0.178121
# sex        -0.074955  1.000000 -0.038832  0.109387  0.070786  0.169959
# age         0.169938 -0.038832  1.000000 -0.130196 -0.138521 -0.072088
# Medu       -0.235114  0.109387 -0.130196  1.000000  0.642063  0.462509
# Fedu       -0.187611  0.070786 -0.138521  0.642063  1.000000  0.279218
# Mjob       -0.178121  0.169959 -0.072088  0.462509  0.279218  1.000000
# Fjob       -0.058046  0.083938 -0.045305  0.156851  0.209255  0.202347
# reason     -0.195897 -0.011920 -0.024657  0.143012  0.080261  0.080740
# guardian    0.038027  0.006987  0.210603 -0.116713  0.004411 -0.090437
# traveltime  0.258834  0.042508  0.049216 -0.238181 -0.196328 -0.150697
# studytime  -0.133255 -0.239972 -0.007870  0.090616  0.033458  0.032181
# failures    0.066856  0.065543  0.282364 -0.187769 -0.191390 -0.089995
# ...

# %%
plt.figure(figsize=(20,20))  # on this line I just set the size of figure to 12 by 10.
p=sns.heatmap(data.corr(), annot=True,cmap ='RdYlGn')

# %%
data.drop(['Fedu','Dalc'],axis=1,inplace=True)

# %%
data
# Out:
#       school  sex  age  Medu  Mjob  Fjob  reason  guardian  traveltime  \
# 0          0    0   18     4     0     4       0         0           2
# 1          0    0   17     1     0     2       0         1           1
# 2          0    0   15     1     0     2       1         0           1
# 3          0    0   15     4     1     3       2         0           1
# 4          0    0   16     3     2     2       2         1           1
# ...      ...  ...  ...   ...   ...   ...     ...       ...         ...
# 1039       1    0   19     2     3     2       0         0           1
# 1040       1    0   18     3     4     3       0         0           1
# 1041       1    0   18     1     2     2       0         0           2
# 1042       1    1   17     3     3     3       0         0           2
# 1043       1    1   18     3     3     2       0         0           3
#
#       studytime  ...  nursery  higher  internet  romantic  freetime  goout  \
# ...

# %%
columns=data.columns.tolist()
columns=[c for c in columns if c not in ['G3']]
target='G3'

x=data[columns]
y=data[target]

print(x.shape)
print(y.shape)
# Out:
# (1044, 24)
# (1044,)

# %%
# from sklearn.preprocessing import StandardScaler
# sc_X = StandardScaler()
# x =  pd.DataFrame(sc_X.fit_transform(x),
#         columns=[c for c in columns ])

# %%
x.head()
# Out:
#    school  sex  age  Medu  Mjob  Fjob  reason  guardian  traveltime  \
# 0       0    0   18     4     0     4       0         0           2
# 1       0    0   17     1     0     2       0         1           1
# 2       0    0   15     1     0     2       1         0           1
# 3       0    0   15     4     1     3       2         0           1
# 4       0    0   16     3     2     2       2         1           1
#
#    studytime  ...  activities  nursery  higher  internet  romantic  freetime  \
# 0          2  ...           0        1       1         0         0         3
# 1          2  ...           0        0       1         1         0         3
# 2          2  ...           0        1       1         1         0         3
# 3          3  ...           1        1       1         1         1         2
# 4          2  ...           0        1       1         0         0         3
#
#    goout  Walc  health  absences
# 0      4     1       3         6
# ...

# %%
from sklearn.model_selection import train_test_split                    #train tset split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=355)

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(reg.score(x_train,y_train))
print(reg.score(x_train,y_train))
# Out:
# 0.2318145112906237
# 0.2318145112906237

# %%
pred=reg.predict(x_test)

# %%
pred
# Out:
# array([ 9.48031067,  8.90572886, 11.18913999, 13.90136402, 10.67365861,
#        10.58495723, 13.23461295,  9.93780341,  6.65944657,  9.9838679 ,
#        12.21902565, 11.23678205, 13.67056649, 10.94580285, 10.91808691,
#        12.56180827,  8.32321793, 10.21280498, 13.14250606, 12.59834823,
#         5.88801077, 14.45957345, 11.88936668, 12.40194323, 10.58091398,
#        10.5966054 , 12.77560942, 13.90136402, 12.20297574,  9.9769582 ,
#        12.82478352, 12.03646121, 11.20628331,  9.74051928,  4.52749943,
#        13.04987863, 12.15114806,  6.58782809, 10.81578359, 13.32206139,
#        10.34516586,  8.81250331, 12.83914608, 12.10584954, 12.4642596 ,
#        13.09783368, 12.48742891,  9.55641891,  5.76316692, 12.02817321,
#        14.04954045, 10.69764959, 12.28124297, 11.20410428, 13.45563548,
#        12.49967395, 13.28973961, 12.91094408, 11.53578543, 12.07563087,
#        11.18829974, 11.45744863, 12.36365614, 14.13745916, 10.67139   ,
# ...

# %%
sns.distplot(y_test)

# %%
sns.distplot(pred)

# %%
sns.distplot(y_test-pred)

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
#hyperparams
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
rf=RandomForestRegressor()

# %%
rf_random= RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 10, cv = 5, verbose=2, random_state=42, n_jobs = 1)

# %%
rf_random.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   0.9s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.0s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=   1.2s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=   1.2s
# ...

# %%
predictions=rf_random.predict(x_test)

# %%
predictions
# Out:
# array([ 2.76135068,  9.53641372, 11.40731557, 12.73529719, 10.46202522,
#        12.11422264, 14.11189104,  9.82794716,  9.29361739, 10.20388205,
#        10.88340992, 11.28455001, 13.64061464, 12.08230227, 12.30451491,
#        12.33470957,  9.89242555, 11.46968353, 12.91062734, 12.78255839,
#         8.70033371, 13.77303681, 10.79175028, 14.84163512, 12.2507197 ,
#         9.19050742, 11.79133668, 12.73529719, 13.5156953 , 10.71115902,
#        13.36865181, 11.57090769, 10.50592428,  9.24045868,  4.25165219,
#        14.04409923, 11.86932495,  9.59634244, 11.43657176,  9.89400866,
#        10.15786676,  9.38186738, 12.78304236, 12.40988277, 12.0453244 ,
#        12.7499967 , 11.706166  ,  9.77332676,  3.86139236, 12.3881301 ,
#        13.81968233, 11.51528521, 12.93416797, 11.43059272, 12.10328638,
#        14.15037908, 11.51020723, 13.77378015, 11.850001  ,  9.54944596,
#        12.20939686,  3.74357129, 12.35197482, 14.85771645, 11.6962033 ,
# ...

# %%
sns.distplot(y_test)

# %%
sns.distplot(predictions)

# %%
sns.distplot(y_test-predictions)

# %% [markdown]
# We can observe that the y_test-predictions is forming almost a smooth bell curve and so we can say that the Random forest Regressor model is performing very good .

# %%
plt.scatter(y_test,predictions)

# %%
# !pip install xgboost

# %%
import xgboost as xgb
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV

# %%
model = XGBRegressor()
parameters = {' learning_rate':[1,0.5,0.1,0.01,0.001], #so called `eta` value
              'max_depth': [5, 6, 7],
              'min_child_weight': [4],
              'n_estimators': [500]}

# %%
xgb_grid = GridSearchCV(model,
                        parameters,
                        cv = 2,
                        n_jobs = 5,
                        verbose=True)

xgb_grid.fit(x_train,
         y_train)
# Out:
# Fitting 2 folds for each of 15 candidates, totalling 30 fits
# [05:48:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: {  learning_rate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# GridSearchCV(cv=2,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, gamma=None,
#                                     gpu_id=None, importance_type='gain',
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_delta_step=None,
# ...

# %%
print(xgb_grid.best_score_)
print(xgb_grid.best_params_)
# Out:
# 0.1405783582273632
# {' learning_rate': 1, 'max_depth': 7, 'min_child_weight': 4, 'n_estimators': 500}

# %%
prediction=xgb_grid.predict(x_test)

# %%
prediction
# Out:
# array([ 2.6588564 , 11.0924    , 11.838972  , 10.809704  ,  9.5916815 ,
#        10.934801  , 14.276878  , 11.368421  ,  9.754928  ,  8.278976  ,
#        10.751852  , 11.454782  , 13.956022  , 12.362289  , 11.068324  ,
#        12.694118  ,  8.957008  , 10.965036  , 13.434515  , 12.495525  ,
#         9.659878  , 14.999771  ,  9.230653  , 15.40647   , 10.832588  ,
#        10.243454  , 12.412581  , 10.809704  , 16.000385  , 10.99965   ,
#        13.197225  , 11.368077  ,  9.375702  ,  8.834263  ,  1.429461  ,
#        13.972654  ,  7.5761256 ,  9.346641  , 11.804447  , 11.0875025 ,
#        10.937468  ,  8.566158  , 12.954253  , 12.584516  , 12.99956   ,
#        12.885402  ,  8.883686  ,  9.398925  ,  3.167745  , 12.40254   ,
#        16.439178  , 11.99989   , 12.47425   , 10.3036175 , 11.820914  ,
#        13.997887  , 11.878457  , 15.270001  , 12.604571  , 13.859716  ,
#        10.925269  ,  4.1384783 , 10.372439  , 15.422541  , 11.435773  ,
# ...

# %%
sns.distplot(y_test)

# %%
sns.distplot(prediction)

# %%
sns.distplot(y_test-prediction)

# %%
plt.scatter(y_test,predictions)

# %% [markdown]
# From the distplot we can observe that the y_test and prediction are almost similar and the xgboost regressor is performing good but slightly less than RandomForestRegressor

# %% [markdown]
# From all the  three models we can observe that the Randomforestregressor model is performing the best.
